# %%
# 1. Copy the entire code repository from our "code dataset"
#    This path matches your new setup.
# !cp -r /kaggle/input/rsna2025/rsna2025 /kaggle/working/rsna_project

# 2. Move into our new project directory
# %cd /kaggle/working/rsna_project

# 3. Install system dependencies (dcm2niix)
print("--- Installing dcm2niix ---")
# !apt-get update
# !apt-get install -y dcm2niix

# 4. Install all Python packages from the requirements file
print("\n--- Installing Python packages ---")
# !pip install -r pip_packages/requirements.txt

# 5. Install the custom nnU-Net
print("\n--- Installing local nnU-Net ---")
# !pip install -e ./nnUNet

print("\n✅ Setup complete! All code is local and all packages are installed.")
# Out:
# /kaggle/working/rsna_project
# --- Installing dcm2niix ---
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,138 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,825 kB]
# Get:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,289 kB]
# Hit:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,595 kB]
# Hit:14 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:15 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,450 kB]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,530 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [6,173 kB]
# Get:18 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [5,982 kB]
# Get:19 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [38.5 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,858 kB]
# Fetched 37.3 MB in 3s (12.0 MB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libyaml-cpp0.7
# The following NEW packages will be installed:
#   dcm2niix libyaml-cpp0.7
# 0 upgraded, 2 newly installed, 0 to remove and 169 not upgraded.
# Need to get 354 kB of archives.
# After this operation, 1,231 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libyaml-cpp0.7 amd64 0.7.0+dfsg-8build1 [97.7 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 dcm2niix amd64 1.0.20211006-1build1 [256 kB]
# Fetched 354 kB in 1s (671 kB/s)
# Selecting previously unselected package libyaml-cpp0.7:amd64.
# (Reading database ... 128639 files and directories currently installed.)
# Preparing to unpack .../libyaml-cpp0.7_0.7.0+dfsg-8build1_amd64.deb ...
# Unpacking libyaml-cpp0.7:amd64 (0.7.0+dfsg-8build1) ...
# Selecting previously unselected package dcm2niix.
# Preparing to unpack .../dcm2niix_1.0.20211006-1build1_amd64.deb ...
# Unpacking dcm2niix (1.0.20211006-1build1) ...
# Setting up libyaml-cpp0.7:amd64 (0.7.0+dfsg-8build1) ...
# Setting up dcm2niix (1.0.20211006-1build1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
#
# --- Installing Python packages ---
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu124
# Collecting lightning>=2.0.0 (from -r pip_packages/requirements.txt (line 6))
#   Downloading lightning-2.5.6-py3-none-any.whl.metadata (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: torchmetrics>=0.11.4 in /usr/local/lib/python3.11/dist-packages (from -r pip_packages/requirements.txt (line 7)) (1.8.2)
# Collecting hydra-core==1.3.2 (from -r pip_packages/requirements.txt (line 10))
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting hydra-colorlog==1.2.0 (from -r pip_packages/requirements.txt (line 11))
#   Downloading hydra_colorlog-1.2.0-py3-none-any.whl.metadata (949 bytes)
# Collecting hydra-optuna-sweeper==1.2.0 (from -r pip_packages/requirements.txt (line 12))
#   Downloading hydra_optuna_sweeper-1.2.0-py3-none-any.whl.metadata (1.0 kB)
# Collecting rootutils==1.0.7 (from -r pip_packages/requirements.txt (line 22))
#   Downloading rootutils-1.0.7-py3-none-any.whl.metadata (4.7 kB)
# Collecting pre-commit==4.2.0 (from -r pip_packages/requirements.txt (line 23))
#   Downloading pre_commit-4.2.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting tensorrt-cu12==10.7.0.post1 (from -r pip_packages/requirements.txt (line 29))
#   Downloading tensorrt_cu12-10.7.0.post1.tar.gz (18 kB)
#   Preparing metadata (setup.py) ... done
# Collecting torch-tensorrt==2.6.0 (from -r pip_packages/requirements.txt (line 30))
#   Downloading https://download.pytorch.org/whl/cu124/torch_tensorrt-2.6.0%2Bcu124-cp311-cp311-linux_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from -r pip_packages/requirements.txt (line 31)) (3.2.0)
# Requirement already satisfied: nibabel==5.3.2 in /usr/local/lib/python3.11/dist-packages (from -r pip_packages/requirements.txt (line 34)) (5.3.2)
# Requirement already satisfied: pydicom==3.0.1 in /usr/local/lib/python3.11/dist-packages (from -r pip_packages/requirements.txt (line 35)) (3.0.1)
# Collecting pylibjpeg==2.0.1 (from -r pip_packages/requirements.txt (line 36))
#   Downloading pylibjpeg-2.0.1-py3-none-any.whl.metadata (7.8 kB)
# Collecting pylibjpeg-libjpeg==2.3.0 (from -r pip_packages/requirements.txt (line 37))
#   Downloading pylibjpeg_libjpeg-2.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# Collecting python-gdcm==3.0.26 (from -r pip_packages/requirements.txt (line 38))
#   Downloading python_gdcm-3.0.26-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: h5py==3.14.0 in /usr/local/lib/python3.11/dist-packages (from -r pip_packages/requirements.txt (line 39)) (3.14.0)
# Collecting zarr==3.1.1 (from -r pip_packages/requirements.txt (line 40))
#   Downloading zarr-3.1.1-py3-none-any.whl.metadata (10 kB)
# Collecting monai==1.5.0 (from -r pip_packages/requirements.txt (line 41))
#   Downloading monai-1.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting batchgeneratorsv2==0.3.0 (from -r pip_packages/requirements.txt (line 42))
#   Downloading batchgeneratorsv2-0.3.0.tar.gz (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting acvl-utils==0.2.5 (from -r pip_packages/requirements.txt (line 45))
#   Downloading acvl_utils-0.2.5.tar.gz (29 kB)
#   Preparing metadata (setup.py) ... done
# Collecting argparse==1.4.0 (from -r pip_packages/requirements.txt (line 46))
#   Downloading argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting connected-components-3d==3.24.0 (from -r pip_packages/requirements.txt (line 47))
#   Downloading connected_components_3d-3.24.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (32 kB)
# Collecting dynamic-network-architectures==0.4.2 (from -r pip_packages/requirements.txt (line 48))
#   Downloading dynamic_network_architectures-0.4.2.tar.gz (28 kB)
#   Preparing metadata (setup.py) ... done
# Collecting imagecodecs==2025.8.2 (from -r pip_packages/requirements.txt (line 49))
#   Downloading imagecodecs-2025.8.2-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (20 kB)
# Collecting yacs==0.1.8 (from -r pip_packages/requirements.txt (line 50))
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /usr/local/lib/python3.11/dist-packages (from hydra-core==1.3.2->-r pip_packages/requirements.txt (line 10)) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.11/dist-packages (from hydra-core==1.3.2->-r pip_packages/requirements.txt (line 10)) (4.9.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from hydra-core==1.3.2->-r pip_packages/requirements.txt (line 10)) (25.0)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from hydra-colorlog==1.2.0->-r pip_packages/requirements.txt (line 11)) (6.10.1)
# Collecting optuna<3.0.0,>=2.10.0 (from hydra-optuna-sweeper==1.2.0->-r pip_packages/requirements.txt (line 12))
#   Downloading optuna-2.10.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: python-dotenv>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from rootutils==1.0.7->-r pip_packages/requirements.txt (line 22)) (1.2.1)
# Collecting cfgv>=2.0.0 (from pre-commit==4.2.0->-r pip_packages/requirements.txt (line 23))
#   Downloading cfgv-3.4.0-py2.py3-none-any.whl.metadata (8.5 kB)
# Collecting identify>=1.0.0 (from pre-commit==4.2.0->-r pip_packages/requirements.txt (line 23))
#   Downloading identify-2.6.15-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting nodeenv>=0.11.1 (from pre-commit==4.2.0->-r pip_packages/requirements.txt (line 23))
#   Downloading nodeenv-1.9.1-py2.py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from pre-commit==4.2.0->-r pip_packages/requirements.txt (line 23)) (6.0.3)
# Collecting virtualenv>=20.10.0 (from pre-commit==4.2.0->-r pip_packages/requirements.txt (line 23))
#   Downloading virtualenv-20.35.4-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: torch==2.6.0 in /usr/local/lib/python3.11/dist-packages (from torch-tensorrt==2.6.0->-r pip_packages/requirements.txt (line 30)) (2.6.0+cu124)
# Collecting tensorrt<10.8.0,>=10.7.0.post1 (from torch-tensorrt==2.6.0->-r pip_packages/requirements.txt (line 30))
#   Downloading tensorrt-10.7.0.post1.tar.gz (35 kB)
#   Preparing metadata (setup.py) ... done
# Collecting tensorrt-cu12-bindings<10.8.0,>=10.7.0 (from torch-tensorrt==2.6.0->-r pip_packages/requirements.txt (line 30))
#   Downloading tensorrt_cu12_bindings-10.7.0.post1-cp311-none-manylinux_2_17_x86_64.whl.metadata (628 bytes)
# Collecting tensorrt-cu12-libs<10.8.0,>=10.7.0 (from torch-tensorrt==2.6.0->-r pip_packages/requirements.txt (line 30))
#   Downloading tensorrt_cu12_libs-10.7.0.post1.tar.gz (710 bytes)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torch-tensorrt==2.6.0->-r pip_packages/requirements.txt (line 30)) (1.26.4)
# Requirement already satisfied: typing-extensions>=4.7.0 in /usr/local/lib/python3.11/dist-packages (from torch-tensorrt==2.6.0->-r pip_packages/requirements.txt (line 30)) (4.15.0)
# Requirement already satisfied: importlib-resources>=5.12 in /usr/local/lib/python3.11/dist-packages (from nibabel==5.3.2->-r pip_packages/requirements.txt (line 34)) (6.5.2)
# Collecting numpy (from torch-tensorrt==2.6.0->-r pip_packages/requirements.txt (line 30))
#   Downloading numpy-2.3.4-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 60.8 kB/s eta 0:00:0000:01
# Collecting donfig>=0.8 (from zarr==3.1.1->-r pip_packages/requirements.txt (line 40))
#   Downloading donfig-0.8.1.post1-py3-none-any.whl.metadata (5.0 kB)
# Collecting numcodecs>=0.14 (from numcodecs[crc32c]>=0.14->zarr==3.1.1->-r pip_packages/requirements.txt (line 40))
#   Downloading numcodecs-0.16.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Collecting fft-conv-pytorch (from batchgeneratorsv2==0.3.0->-r pip_packages/requirements.txt (line 42))
#   Downloading fft_conv_pytorch-1.2.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting batchgenerators>=0.25 (from batchgeneratorsv2==0.3.0->-r pip_packages/requirements.txt (line 42))
#   Downloading batchgenerators-0.25.1.tar.gz (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 5.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: SimpleITK in /usr/local/lib/python3.11/dist-packages (from acvl-utils==0.2.5->-r pip_packages/requirements.txt (line 45)) (2.5.2)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (from acvl-utils==0.2.5->-r pip_packages/requirements.txt (line 45)) (0.25.2)
# Requirement already satisfied: blosc2>=3.0.0b4 in /usr/local/lib/python3.11/dist-packages (from acvl-utils==0.2.5->-r pip_packages/requirements.txt (line 45)) (3.6.1)
# Requirement already satisfied: timm in /usr/local/lib/python3.11/dist-packages (from dynamic-network-architectures==0.4.2->-r pip_packages/requirements.txt (line 48)) (1.0.19)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from dynamic-network-architectures==0.4.2->-r pip_packages/requirements.txt (line 48)) (0.8.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torch-tensorrt==2.6.0->-r pip_packages/requirements.txt (line 30)) (3.20.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torch-tensorrt==2.6.0->-r pip_packages/requirements.txt (line 30)) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torch-tensorrt==2.6.0->-r pip_packages/requirements.txt (line 30)) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torch-tensorrt==2.6.0->-r pip_packages/requirements.txt (line 30)) (2025.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch==2.6.0->torch-tensorrt==2.6.0->-r pip_packages/requirements.txt (line 30))
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 78.8 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch==2.6.0->torch-tensorrt==2.6.0->-r pip_packages/requirements.txt (line 30))
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.4 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch==2.6.0->torch-tensorrt==2.6.0->-r pip_packages/requirements.txt (line 30))
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 104.3 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch==2.6.0->torch-tensorrt==2.6.0->-r pip_packages/requirements.txt (line 30))
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch==2.6.0->torch-tensorrt==2.6.0->-r pip_packages/requirements.txt (line 30))
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch==2.6.0->torch-tensorrt==2.6.0->-r pip_packages/requirements.txt (line 30))
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.3 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch==2.6.0->torch-tensorrt==2.6.0->-r pip_packages/requirements.txt (line 30))
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 31.9 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch==2.6.0->torch-tensorrt==2.6.0->-r pip_packages/requirements.txt (line 30))
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.5 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch==2.6.0->torch-tensorrt==2.6.0->-r pip_packages/requirements.txt (line 30))
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torch-tensorrt==2.6.0->-r pip_packages/requirements.txt (line 30)) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torch-tensorrt==2.6.0->-r pip_packages/requirements.txt (line 30)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torch-tensorrt==2.6.0->-r pip_packages/requirements.txt (line 30)) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch==2.6.0->torch-tensorrt==2.6.0->-r pip_packages/requirements.txt (line 30))
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 88.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torch-tensorrt==2.6.0->-r pip_packages/requirements.txt (line 30)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch==2.6.0->torch-tensorrt==2.6.0->-r pip_packages/requirements.txt (line 30)) (1.3.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from lightning>=2.0.0->-r pip_packages/requirements.txt (line 6)) (0.15.2)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /usr/local/lib/python3.11/dist-packages (from lightning>=2.0.0->-r pip_packages/requirements.txt (line 6)) (4.67.1)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.11/dist-packages (from lightning>=2.0.0->-r pip_packages/requirements.txt (line 6)) (2.5.5)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from batchgenerators>=0.25->batchgeneratorsv2==0.3.0->-r pip_packages/requirements.txt (line 42)) (11.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from batchgenerators>=0.25->batchgeneratorsv2==0.3.0->-r pip_packages/requirements.txt (line 42)) (1.15.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from batchgenerators>=0.25->batchgeneratorsv2==0.3.0->-r pip_packages/requirements.txt (line 42)) (1.2.2)
# Requirement already satisfied: future in /usr/local/lib/python3.11/dist-packages (from batchgenerators>=0.25->batchgeneratorsv2==0.3.0->-r pip_packages/requirements.txt (line 42)) (1.0.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from batchgenerators>=0.25->batchgeneratorsv2==0.3.0->-r pip_packages/requirements.txt (line 42)) (2.2.3)
# Collecting unittest2 (from batchgenerators>=0.25->batchgeneratorsv2==0.3.0->-r pip_packages/requirements.txt (line 42))
#   Downloading unittest2-1.1.0-py2.py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: threadpoolctl in /usr/local/lib/python3.11/dist-packages (from batchgenerators>=0.25->batchgeneratorsv2==0.3.0->-r pip_packages/requirements.txt (line 42)) (3.6.0)
# Requirement already satisfied: ndindex in /usr/local/lib/python3.11/dist-packages (from blosc2>=3.0.0b4->acvl-utils==0.2.5->-r pip_packages/requirements.txt (line 45)) (1.10.0)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.11/dist-packages (from blosc2>=3.0.0b4->acvl-utils==0.2.5->-r pip_packages/requirements.txt (line 45)) (1.1.2)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from blosc2>=3.0.0b4->acvl-utils==0.2.5->-r pip_packages/requirements.txt (line 45)) (4.5.0)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.11/dist-packages (from blosc2>=3.0.0b4->acvl-utils==0.2.5->-r pip_packages/requirements.txt (line 45)) (2.11.0)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from blosc2>=3.0.0b4->acvl-utils==0.2.5->-r pip_packages/requirements.txt (line 45)) (9.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from blosc2>=3.0.0b4->acvl-utils==0.2.5->-r pip_packages/requirements.txt (line 45)) (2.32.5)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.0->-r pip_packages/requirements.txt (line 6)) (3.13.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from lightning-utilities<2.0,>=0.10.0->lightning>=2.0.0->-r pip_packages/requirements.txt (line 6)) (75.2.0)
# Collecting crc32c>=2.7 (from numcodecs[crc32c]>=0.14->zarr==3.1.1->-r pip_packages/requirements.txt (line 40))
#   Downloading crc32c-2.8-cp311-cp311-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (7.8 kB)
# Requirement already satisfied: alembic in /usr/local/lib/python3.11/dist-packages (from optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->-r pip_packages/requirements.txt (line 12)) (1.17.1)
# Collecting cliff (from optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->-r pip_packages/requirements.txt (line 12))
#   Downloading cliff-4.11.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting cmaes>=0.8.2 (from optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->-r pip_packages/requirements.txt (line 12))
#   Downloading cmaes-0.12.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->-r pip_packages/requirements.txt (line 12)) (2.0.41)
# Collecting distlib<1,>=0.3.7 (from virtualenv>=20.10.0->pre-commit==4.2.0->-r pip_packages/requirements.txt (line 23))
#   Downloading distlib-0.4.0-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image->acvl-utils==0.2.5->-r pip_packages/requirements.txt (line 45)) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image->acvl-utils==0.2.5->-r pip_packages/requirements.txt (line 45)) (2025.6.11)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image->acvl-utils==0.2.5->-r pip_packages/requirements.txt (line 45)) (0.4)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from timm->dynamic-network-architectures==0.4.2->-r pip_packages/requirements.txt (line 48)) (0.21.0+cu124)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.11/dist-packages (from timm->dynamic-network-architectures==0.4.2->-r pip_packages/requirements.txt (line 48)) (0.36.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (from timm->dynamic-network-architectures==0.4.2->-r pip_packages/requirements.txt (line 48)) (0.5.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.0->-r pip_packages/requirements.txt (line 6)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.0->-r pip_packages/requirements.txt (line 6)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.0->-r pip_packages/requirements.txt (line 6)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.0->-r pip_packages/requirements.txt (line 6)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.0->-r pip_packages/requirements.txt (line 6)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.0->-r pip_packages/requirements.txt (line 6)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.0->-r pip_packages/requirements.txt (line 6)) (1.22.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.1.0->optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->-r pip_packages/requirements.txt (line 12)) (3.2.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.11/dist-packages (from alembic->optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->-r pip_packages/requirements.txt (line 12)) (1.3.10)
# Collecting autopage>=0.4.0 (from cliff->optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->-r pip_packages/requirements.txt (line 12))
#   Downloading autopage-0.5.2-py3-none-any.whl.metadata (7.9 kB)
# Collecting cmd2>=1.0.0 (from cliff->optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->-r pip_packages/requirements.txt (line 12))
#   Downloading cmd2-2.7.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: PrettyTable>=0.7.2 in /usr/local/lib/python3.11/dist-packages (from cliff->optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->-r pip_packages/requirements.txt (line 12)) (3.16.0)
# Collecting stevedore>=2.0.1 (from cliff->optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->-r pip_packages/requirements.txt (line 12))
#   Downloading stevedore-5.5.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->timm->dynamic-network-architectures==0.4.2->-r pip_packages/requirements.txt (line 48)) (1.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.6.0->torch-tensorrt==2.6.0->-r pip_packages/requirements.txt (line 30)) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->batchgenerators>=0.25->batchgeneratorsv2==0.3.0->-r pip_packages/requirements.txt (line 42)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->batchgenerators>=0.25->batchgeneratorsv2==0.3.0->-r pip_packages/requirements.txt (line 42)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->batchgenerators>=0.25->batchgeneratorsv2==0.3.0->-r pip_packages/requirements.txt (line 42)) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->blosc2>=3.0.0b4->acvl-utils==0.2.5->-r pip_packages/requirements.txt (line 45)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->blosc2>=3.0.0b4->acvl-utils==0.2.5->-r pip_packages/requirements.txt (line 45)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->blosc2>=3.0.0b4->acvl-utils==0.2.5->-r pip_packages/requirements.txt (line 45)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->blosc2>=3.0.0b4->acvl-utils==0.2.5->-r pip_packages/requirements.txt (line 45)) (2025.10.5)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->batchgenerators>=0.25->batchgeneratorsv2==0.3.0->-r pip_packages/requirements.txt (line 42)) (1.5.2)
# Requirement already satisfied: six>=1.4 in /usr/local/lib/python3.11/dist-packages (from unittest2->batchgenerators>=0.25->batchgeneratorsv2==0.3.0->-r pip_packages/requirements.txt (line 42)) (1.17.0)
# Collecting traceback2 (from unittest2->batchgenerators>=0.25->batchgeneratorsv2==0.3.0->-r pip_packages/requirements.txt (line 42))
#   Downloading traceback2-1.4.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: pyperclip>=1.8 in /usr/local/lib/python3.11/dist-packages (from cmd2>=1.0.0->cliff->optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->-r pip_packages/requirements.txt (line 12)) (1.9.0)
# Collecting rich-argparse>=1.7.1 (from cmd2>=1.0.0->cliff->optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->-r pip_packages/requirements.txt (line 12))
#   Downloading rich_argparse-1.7.2-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: wcwidth>=0.2.10 in /usr/local/lib/python3.11/dist-packages (from cmd2>=1.0.0->cliff->optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->-r pip_packages/requirements.txt (line 12)) (0.2.13)
# Collecting linecache2 (from traceback2->unittest2->batchgenerators>=0.25->batchgeneratorsv2==0.3.0->-r pip_packages/requirements.txt (line 42))
#   Downloading linecache2-1.0.0-py2.py3-none-any.whl.metadata (1000 bytes)
# Requirement already satisfied: rich>=11.0.0 in /usr/local/lib/python3.11/dist-packages (from rich-argparse>=1.7.1->cmd2>=1.0.0->cliff->optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->-r pip_packages/requirements.txt (line 12)) (14.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.0.0->rich-argparse>=1.7.1->cmd2>=1.0.0->cliff->optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->-r pip_packages/requirements.txt (line 12)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.0.0->rich-argparse>=1.7.1->cmd2>=1.0.0->cliff->optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->-r pip_packages/requirements.txt (line 12)) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=11.0.0->rich-argparse>=1.7.1->cmd2>=1.0.0->cliff->optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->-r pip_packages/requirements.txt (line 12)) (0.1.2)
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 8.0 MB/s eta 0:00:00
# Downloading hydra_colorlog-1.2.0-py3-none-any.whl (3.6 kB)
# Downloading hydra_optuna_sweeper-1.2.0-py3-none-any.whl (8.5 kB)
# Downloading rootutils-1.0.7-py3-none-any.whl (6.4 kB)
# Downloading pre_commit-4.2.0-py2.py3-none-any.whl (220 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.7/220.7 kB 14.9 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/cu124/torch_tensorrt-2.6.0%2Bcu124-cp311-cp311-linux_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 86.5 MB/s eta 0:00:00:00:01
# Downloading pylibjpeg-2.0.1-py3-none-any.whl (24 kB)
# Downloading pylibjpeg_libjpeg-2.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 67.2 MB/s eta 0:00:00:00:01
# Downloading python_gdcm-3.0.26-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 100.3 MB/s eta 0:00:0000:010:01
# Downloading zarr-3.1.1-py3-none-any.whl (255 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.4/255.4 kB 15.5 MB/s eta 0:00:00
# Downloading monai-1.5.0-py3-none-any.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 74.7 MB/s eta 0:00:00:00:01
# Downloading argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Downloading connected_components_3d-3.24.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 81.4 MB/s eta 0:00:00:00:01
# Downloading imagecodecs-2025.8.2-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (26.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.4/26.4 MB 72.8 MB/s eta 0:00:00:00:0100:01
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Downloading lightning-2.5.6-py3-none-any.whl (827 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 827.9/827.9 kB 44.1 MB/s eta 0:00:00
# Downloading cfgv-3.4.0-py2.py3-none-any.whl (7.2 kB)
# Downloading donfig-0.8.1.post1-py3-none-any.whl (21 kB)
# Downloading identify-2.6.15-py2.py3-none-any.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 kB 6.3 MB/s eta 0:00:00
# Downloading nodeenv-1.9.1-py2.py3-none-any.whl (22 kB)
# Downloading numcodecs-0.16.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 103.2 MB/s eta 0:00:0000:0100:01
# Downloading numpy-2.3.4-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 95.8 MB/s eta 0:00:00:00:0100:01
# Downloading optuna-2.10.1-py3-none-any.whl (308 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.2/308.2 kB 21.0 MB/s eta 0:00:00
# Downloading tensorrt_cu12_bindings-10.7.0.post1-cp311-none-manylinux_2_17_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 51.2 MB/s eta 0:00:00
# Downloading virtualenv-20.35.4-py3-none-any.whl (6.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 100.7 MB/s eta 0:00:0000:01
# Downloading fft_conv_pytorch-1.2.0-py3-none-any.whl (6.8 kB)
# Downloading cmaes-0.12.0-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.5/64.5 kB 4.7 MB/s eta 0:00:00
# Downloading crc32c-2.8-cp311-cp311-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (80 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.2/80.2 kB 5.0 MB/s eta 0:00:00
# Downloading distlib-0.4.0-py2.py3-none-any.whl (469 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 29.6 MB/s eta 0:00:00
# Downloading cliff-4.11.0-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.4/84.4 kB 6.0 MB/s eta 0:00:00
# Downloading unittest2-1.1.0-py2.py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 7.8 MB/s eta 0:00:00
# Downloading autopage-0.5.2-py3-none-any.whl (30 kB)
# Downloading cmd2-2.7.0-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.3/154.3 kB 9.6 MB/s eta 0:00:00
# Downloading stevedore-5.5.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 2.9 MB/s eta 0:00:00
# Downloading traceback2-1.4.0-py2.py3-none-any.whl (16 kB)
# Downloading rich_argparse-1.7.2-py3-none-any.whl (25 kB)
# Downloading linecache2-1.0.0-py2.py3-none-any.whl (12 kB)
# Building wheels for collected packages: tensorrt-cu12, batchgeneratorsv2, acvl-utils, dynamic-network-architectures, batchgenerators, tensorrt, tensorrt-cu12-libs
#   Building wheel for tensorrt-cu12 (setup.py) ... done
#   Created wheel for tensorrt-cu12: filename=tensorrt_cu12-10.7.0.post1-py2.py3-none-any.whl size=17632 sha256=15ac32785fca1bef367fd5a2970c27c821ae274b361283139a2d346a609d1467
#   Stored in directory: /root/.cache/pip/wheels/31/95/0d/93bc3231ac7802cf65d5600a1848f0052c3b34bf77a8138c28
#   Building wheel for batchgeneratorsv2 (pyproject.toml) ... done
#   Created wheel for batchgeneratorsv2: filename=batchgeneratorsv2-0.3.0-py3-none-any.whl size=65215 sha256=e71033e7032a9cd4f3b96b7f834c9e3151146dac92d4c3d3144092b3ccf86663
#   Stored in directory: /root/.cache/pip/wheels/c0/c1/8f/94ca60255dbbadf27e1da4885002a6943c95b067b8e2dd39ea
#   Building wheel for acvl-utils (setup.py) ... done
#   Created wheel for acvl-utils: filename=acvl_utils-0.2.5-py3-none-any.whl size=27213 sha256=524778f947f89f0827278f354a88f5411ceefffeb1ef5ef739b2c5548fa721e9
#   Stored in directory: /root/.cache/pip/wheels/3f/8c/10/dcba79e0b2d1d463605233cec1fc6cfad47af5230b8985e464
#   Building wheel for dynamic-network-architectures (setup.py) ... done
#   Created wheel for dynamic-network-architectures: filename=dynamic_network_architectures-0.4.2-py3-none-any.whl size=39025 sha256=2a88fc535a876eead3c48b503ccaa7acb8059a10ca1b04709f5a69196839015c
#   Stored in directory: /root/.cache/pip/wheels/07/a9/c3/fcdf69ef4481860db91d0dc2466f63df8c3933262424a23f54
#   Building wheel for batchgenerators (setup.py) ... done
#   Created wheel for batchgenerators: filename=batchgenerators-0.25.1-py3-none-any.whl size=93088 sha256=03e8c18e955463cb7a783b06ad1809983d595a010ae3a891135bbbfe274ceda8
#   Stored in directory: /root/.cache/pip/wheels/56/11/c7/fadca30e054c602093ffe36ba8a2f0a87dd2f86ac75191d3ed
#   Building wheel for tensorrt (setup.py) ... done
#   Created wheel for tensorrt: filename=tensorrt-10.7.0.post1-py2.py3-none-any.whl size=42170 sha256=4f1d4259432746575e61d7ba1f0f213e1acb5d3563f3307beea2ba8e4596a05c
#   Stored in directory: /root/.cache/pip/wheels/56/f9/fa/d8dc822675c08f0b9f87bb4f080164bb4cf206692e2e62c0ae
#   Building wheel for tensorrt-cu12-libs (pyproject.toml) ... done
#   Created wheel for tensorrt-cu12-libs: filename=tensorrt_cu12_libs-10.7.0.post1-py2.py3-none-manylinux_2_17_x86_64.whl size=2069981220 sha256=ab4b8ef46a113f2e704b4c755c4db89789d70069c806d50683e17811060a09e2
#   Stored in directory: /root/.cache/pip/wheels/7f/37/a3/80b753dffe437ee9003d15cefa3dfb451ade6e484737f97379
# Successfully built tensorrt-cu12 batchgeneratorsv2 acvl-utils dynamic-network-architectures batchgenerators tensorrt tensorrt-cu12-libs
# Installing collected packages: tensorrt-cu12-bindings, linecache2, distlib, argparse, yacs, virtualenv, traceback2, tensorrt-cu12, stevedore, rootutils, python-gdcm, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, nodeenv, identify, donfig, crc32c, cfgv, autopage, unittest2, tensorrt-cu12-libs, tensorrt, pylibjpeg-libjpeg, pylibjpeg, pre-commit, nvidia-cusparse-cu12, nvidia-cudnn-cu12, numcodecs, imagecodecs, hydra-core, connected-components-3d, cmaes, rich-argparse, nvidia-cusolver-cu12, hydra-colorlog, zarr, cmd2, batchgenerators, torch-tensorrt, monai, fft-conv-pytorch, cliff, acvl-utils, optuna, batchgeneratorsv2, lightning, hydra-optuna-sweeper, dynamic-network-architectures
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75

# %%
# We must be in this directory for the scripts to work
# %cd /kaggle/working/rsna_project

# %%
import pandas as pd
import numpy as np

# --- Create the directory structure the winner's hardcoded scripts expect ---
# !mkdir -p /workspace/data
# !mkdir -p /workspace/data/nnUNet/nnUNet_raw
# !mkdir -p /workspace/data/nnUNet/nnUNet_preprocessed
# !mkdir -p /workspace/data/nnUNet/nnUNet_results

# --- Link Competition Data into /workspace/data ---
# !ln -s /kaggle/input/rsna-intracranial-aneurysm-detection/series /workspace/data/series
# !ln -s /kaggle/input/rsna-intracranial-aneurysm-detection/segmentations /workspace/data/segmentations
# !ln -s /kaggle/input/rsna-intracranial-aneurysm-detection/train_localizers.csv /workspace/data/train_localizers.csv

# --- Copy the error file the script was looking for ---
# !cp /kaggle/working/rsna_project/data/error_data.yaml /workspace/data/error_data.yaml

# --- Set the environment variables to this new location ---
# %env nnUNet_raw="/workspace/data/nnUNet/nnUNet_raw"
# %env nnUNet_preprocessed="/workspace/data/nnUNet/nnUNet_preprocessed"
# %env nnUNet_results="/workspace/data/nnUNet/nnUNet_results"

print("✅ Fixed environment! '/workspace/data' is now set up.")

# %%
import pandas as pd
import numpy as np

# 1. Load the REAL training file from the competition data
full_train_df = pd.read_csv('/kaggle/input/rsna-intracranial-aneurysm-detection/train.csv')

# 2. Get a list of all unique scan IDs
all_scan_ids = full_train_df['SeriesInstanceUID'].unique()
print(f"Total scans in dataset: {len(all_scan_ids)}")

# 3. Select a small sample of scans (e.g., 50)
np.random.seed(42) # for reproducible results
sample_scan_ids = np.random.choice(all_scan_ids, 50, replace=False)

# 4. Filter the main dataframe to ONLY include these 50 scans
sample_df = full_train_df[full_train_df['SeriesInstanceUID'].isin(sample_scan_ids)]

# 5. Save this SMALL dataframe to the location the code expects
sample_df.to_csv('/workspace/data/train.csv', index=False)
print(f"✅ Created a sample 'train.csv' with {len(sample_scan_ids)} scans at /workspace/data/.")

# %%
import SimpleITK as sitk
import pydicom
import joblib
import subprocess
from tqdm import tqdm
from pathlib import Path
import numpy as np
import pandas as pd
import os
import json

# --- 0. SETUP & SANITY CHECKS ---
# Ensure we are in the correct directory
# %cd /kaggle/working/rsna_project
print(f"Current directory: {os.getcwd()}")

# Force-set environment variables again
os.environ['nnUNet_raw'] = "/workspace/data/nnUNet/nnUNet_raw"
os.environ['nnUNet_preprocessed'] = "/workspace/data/nnUNet/nnUNet_preprocessed"
os.environ['nnUNet_results'] = "/workspace/data/nnUNet/nnUNet_results"
print("✅ Environment variables set.")

# --- 1/8: DICOM CONVERSION (ROBUST VERSION) ---
print("\n--- 1/8: Converting DICOM to NIfTI ---")

# 1. Define the config 
class CFG:
    img_dir = Path("/workspace/data/series")
    out_dir = Path("/workspace/data/series_niix")
    csv_dir = Path("/workspace/data")
    error_dir = Path("/workspace/data/error_data")
    num_workers = os.cpu_count()
    
# 2. Define the conversion functions 
def dcm2niix(src_path: Path, dst_path: Path, series_id: str) -> int:
    dst_path.mkdir(parents=True, exist_ok=True)
    cmd = ["dcm2niix", "-o", str(dst_path), "-f", f"{series_id}", "-z", "y", "-b", "n", "-m", "2", str(src_path)]
    try:
        subprocess.run(cmd, check=True, capture_output=True, text=True, timeout=300)
    except (subprocess.CalledProcessError, subprocess.TimeoutExpired):
        return 1
    return 0

def run_dcm2niix(series_ids: list[str]):
    print(f"Running dcm2niix for {len(series_ids)} series...")
    results = joblib.Parallel(n_jobs=CFG.num_workers)(
        joblib.delayed(dcm2niix)(
            src_path=CFG.img_dir / series_id,
            dst_path=CFG.out_dir / series_id,
            series_id=series_id,
        )
        for series_id in tqdm(series_ids, desc="Converting")
    )
    success_count = sum(1 for res in results if res == 0)
    print(f"Done: {success_count} success, {len(results) - success_count} failure")

# 3. Run the conversion on OUR 100 scans
try:
    sample_df = pd.read_csv('/workspace/data/train.csv')
    series_ids_to_process = sample_df['SeriesInstanceUID'].tolist()
    print(f"Found {len(series_ids_to_process)} scans to process.")
    run_dcm2niix(series_ids_to_process)
    print("\n✅ DICOM conversion finished.")
except Exception as e:
    print(f"❌ An error occurred during conversion: {e}")

# --- 2/8: Moving error data ---
print("\n--- 2/8: Moving error data ---")
# !python src/my_utils/move_error_data.py

# --- 3/8: Creating nnU-Net Datasets ---
print("\n--- 3/8: Creating nnU-Net Dataset 001 & 003 ---")
# !python src/nnUnet_utils/create_nnunet_dataset.py
# !python src/nnUnet_utils/create_nnunet_dataset.py --dataset-id 3

# --- 4/8: Planning & Preprocessing Dataset 001 (RAM FIX) ---
print("\n--- 4/8: Planning and preprocessing Dataset 001 (3d_fullres only) ---")
# We use -c 3d_fullres to skip the 2d config that crashes RAM
# !nnUNetv2_plan_and_preprocess -d 1 --verify_dataset_integrity -pl nnUNetPlannerResEncM -c 3d_fullres -np 2
print("✅ Preprocessing for Dataset 001 complete.")

# --- 5/8: Planning & Preprocessing Dataset 003 (CORRECT COMMAND) ---
print("\n--- 5/8: Planning and preprocessing Dataset 003 ---")
# This is the correct command to create the '...ForcedLowres' plan
# !nnUNetv2_plan_and_preprocess -d 3 --verify_dataset_integrity -pl nnUNetPlannerResEncMForcedLowres -overwrite_target_spacing 1.0 1.0 1.0 -c 3d_fullres -np 2
print("✅ Planning and Preprocessing for Dataset 003 complete.")

# --- 6/8: JSON Patch (CORRECT FILE NAME) ---
print("\n--- 6/8: Re-running JSON patch with correct file name ---")
plan_file = "/workspace/data/nnUNet/nnUNet_preprocessed/Dataset003_VesselGrouping/nnUNetResEncUNetMPlans_ForcedLowres.json"

try:
    with open(plan_file, 'r') as f: data = json.load(f)
    
    data['plans_per_stage'][0]['patch_size'] = [128, 128, 128]
    
    with open(plan_file, 'w') as f: json.dump(data, f, indent=4)
    print("✅ Patched nnUNet plans.json successfully.")
    
    # 6.2 Re-preprocess Dataset 003 with the new patch size
    print("\n--- 6.2: Re-preprocessing Dataset 003 with new patch size ---")
    # !nnUNetv2_preprocess -d 3 -plans_name nnUNetResEncUNetMPlans_ForcedLowres -c 3d_fullres -np 2
    print("✅ Re-preprocessing for Dataset 003 complete.")
except Exception as e:
    print(f"❌ Error patching JSON. The file '{plan_file}' was not found. {e}")

# --- 7/8 & 8/8: Final Steps ---
print("\n--- 7/8: Creating inference dataset ---")
# !python src/nnUnet_utils/create_nnunet_inference_dataset.py
print("\n--- 8/8: Creating empty classifier dataset ---")
# !mkdir -p /workspace/data/clf_data/imagesTr
# !mkdir -p /workspace/data/clf_data/labelsTr

print("\n\n✅✅✅ Final Preprocessing Complete! ✅✅✅")

# %%
# 1. Delete the bad folder that was created by the failed 'cp' command
print("--- 1/4: Deleting corrupted destination folder ---")
# !rm -rf /kaggle/working/FINAL_PREPROCESSED_DATA

# 2. Re-create the empty, safe directory

# %%
# --- STAGE 1: TRAINING THE nnU-Net SEGMENTATION MODELS ---
# We are training only fold 0, for 15 epochs (which you set manually)

print("--- 1/4: Training Stage 1: Vessel Segmentation (Dataset 001, Fold 0) ---")
# !nnUNetv2_train 1 3d_fullres 0 -p nnUNetPlannerResEncM -tr nnUNetTrainerSkeletonRecall_more_DAv3

print("\n--- 2/4: Training Stage 1: Vessel Grouping (Dataset 003, Fold 0) ---")
# !nnUNetv2_train 3 3d_fullres 0 -p nnUNetResEncUNetMPlans_ForcedLowres -tr RSNA2025Trainer_moreDAv7

# --- STAGE 1: INFERENCE ---
# Now we use the models we just trained to predict on our 100 scans.
# This creates the ROI (Region of Interest) inputs for the next stage.
print("\n--- 3/4: Running Stage 1 Inference (Creating ROIs) ---")
# !python src/my_utils/vessel_segmentation.py

# --- STAGE 2: TRAINING THE CLASSIFIER MODEL ---
# This trains the final model. We override the epochs on the command line.
# trainer.max_epochs=5 tells it to only train for 5 epochs (fast).
print("\n--- 4/4: Training Stage 2: ROI Classifier (Fold 0, 5 Epochs) ---")
# !python src/train.py \
  experiment=251013-seg_tf-v4-nnunet_truncate1-preV6_1-ex_dav6w3-m32g64-e25-w01_005_1-s128_256_256 \
  data.fold=0 \
  trainer.max_epochs=1

print("\n\n✅✅✅ Full Training Pipeline Complete! ✅✅✅")
